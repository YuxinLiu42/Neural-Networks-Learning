# %% [markdown]
# ![gptpipeline](gptpipeline.jpg)

# %% [markdown]
# Data collection
#
# Base model training: pretraining, fine-tuning
#
# RM Dataset
#
# RM training
#
# Mode collapse: chain of thought
#
# Ensemble multiple attempts
#
# Ask for reflection
#
# Tool use / Plugins
#
# Default recommendation
