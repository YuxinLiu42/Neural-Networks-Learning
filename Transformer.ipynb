# %% [markdown]
# Codes for Transformer from https://nlp.seas.harvard.edu/annotated-transformer/

# %%
# !pip install -r requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached torch-2.1.2-cp311-none-macosx_11_0_arm64.whl.metadata (25 kB)
# ...
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# ...
# Using cached torch-2.1.2-cp311-none-macosx_11_0_arm64.whl (59.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 kB 13.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 18.9 MB/s  0:00:01 eta 0:00:01
# ...
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.3-py3-none-any.whl (24 kB)
# ...
#   Created wheel for GPUtil: filename=gputil-1.4.0-py3-none-any.whl size=7437 sha256=4b7b9bc2a755b994854c79797b5c1749393f00f4932c7db4d88e2304e5d2c6a4
# ...
